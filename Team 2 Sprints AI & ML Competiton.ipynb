# %% [markdown]
# # Project: Image Classification
# # By Omar Diab [20p3176]

# %% [markdown]
# # ***Downloading Content***

# %%
# %matplotlib inline

# %%
from __future__ import print_function, division
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
! gdown --id 1pL8D87UZ7ioj43ob14pPkCvJbQdTOwme
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1pL8D87UZ7ioj43ob14pPkCvJbQdTOwme
# To: /content/ConvNext Tiny
# 100% 111M/111M [00:00<00:00, 229MB/s]

# %%
! gdown --id 1fbsnjPsrD2hBWSZdmDmwJpHqsVhQfvhm
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1fbsnjPsrD2hBWSZdmDmwJpHqsVhQfvhm
# To: /content/sprints-ai-and-ml-competition-2022-round-2.zip
# 100% 254M/254M [00:01<00:00, 185MB/s]

# %%
# !unzip "/content/sprints-ai-and-ml-competition-2022-round-2.zip" -d "/content/sprints-ai-and-ml-competition-2022-round-2"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7551.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7560.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7565.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7578.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7581.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7586.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7647.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7652.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7654.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7662.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/767.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7672.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7679.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7681.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7693.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7695.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7698.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7700.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/771.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7715.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7744.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7745.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7751.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7763.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7771.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7780.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7787.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7788.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7813.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7816.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7819.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7820.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7823.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7836.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/784.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7841.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7842.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7845.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7849.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7851.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7865.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7875.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7881.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7885.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/790.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7908.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7909.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7912.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7922.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7928.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7942.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7946.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7960.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7973.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7979.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7984.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/7993.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/800.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8009.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8025.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8043.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8044.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8045.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/805.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8070.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8088.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8092.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8105.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8109.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8118.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8125.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8126.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8136.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8146.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8148.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/816.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8161.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8163.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8169.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8195.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8199.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/820.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8200.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/821.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8211.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8213.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/822.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8222.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8223.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/823.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8235.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8242.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8245.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8250.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8252.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8260.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8266.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/827.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8291.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8296.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8297.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8308.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8327.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8331.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8335.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8343.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8349.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8355.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8356.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8365.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8373.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8377.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8386.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8393.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8404.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8409.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8420.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8433.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8436.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8438.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8441.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8445.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8450.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8455.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8466.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8470.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8472.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8478.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8479.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/848.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8484.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8485.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8486.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8488.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8498.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/85.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8500.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8532.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8536.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8549.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8561.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8564.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/857.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8571.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8573.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8587.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8594.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/860.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8607.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8615.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8617.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8628.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8629.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8635.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8640.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8655.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8656.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/866.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8670.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8676.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8679.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8684.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8685.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8692.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8695.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8703.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8724.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8725.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8734.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8742.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8744.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8749.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8757.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8762.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8766.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8768.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8771.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8773.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8780.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8782.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8791.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8798.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8803.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8811.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8816.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/883.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8831.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/884.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8845.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8855.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8862.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8863.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8881.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8883.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8895.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8902.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8924.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8932.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8934.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8937.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8940.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8960.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8961.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/899.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/8991.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9012.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9023.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9029.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9045.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9046.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9048.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9050.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9064.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9065.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9068.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9070.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9071.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9073.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9083.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9088.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9105.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9120.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9133.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/914.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9146.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9147.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9153.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9155.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9174.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9179.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9186.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9190.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9195.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9209.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9213.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9228.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9229.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9232.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9239.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9252.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9267.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9273.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9276.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9277.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9285.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9286.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9298.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9309.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9311.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/932.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9321.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9324.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9325.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9330.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9340.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9348.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9358.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9360.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9365.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9387.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9393.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9399.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9409.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/941.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9423.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9430.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9434.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9444.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9445.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9455.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9460.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9474.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9493.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/95.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9502.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9528.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9531.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9533.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9534.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9536.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9551.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9553.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/956.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9560.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9561.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9568.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9588.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/959.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9610.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9633.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9639.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/964.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9642.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9643.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9644.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9653.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9669.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9681.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9682.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9686.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9689.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9703.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9719.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/972.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9728.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9739.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9748.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9756.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/976.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9763.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9771.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9776.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9779.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9793.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9799.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9801.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9805.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9806.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9822.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9825.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9832.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9835.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9840.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9851.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9856.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9860.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9861.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9868.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9869.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9884.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9894.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9896.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9901.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9907.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9924.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9928.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9941.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9952.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9957.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9980.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/mountain/9990.jpg
#    creating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10016.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10041.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10053.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10061.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10068.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10071.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10080.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10087.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10093.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10095.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10108.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10114.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10115.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10120.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10122.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10128.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1014.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10143.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10150.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10177.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10183.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/102.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10203.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1021.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1022.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10237.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10245.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10249.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10259.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10262.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1027.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10271.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10274.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10299.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10304.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10309.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10343.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10344.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10345.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1035.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10351.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10373.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10378.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1038.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10382.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10396.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10399.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10416.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10420.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10426.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10428.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10429.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1043.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10433.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10443.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10450.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10451.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10465.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1047.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10473.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10493.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10494.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10525.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10529.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10532.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10543.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10550.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10551.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10556.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10565.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10584.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10595.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10596.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10602.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10619.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10621.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10628.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10644.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10658.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10671.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10683.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10686.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/107.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10706.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10715.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10725.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10739.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10740.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10745.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/1075.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10750.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10753.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10766.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10773.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10775.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10776.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10789.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10802.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10803.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10822.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10826.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10833.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10840.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10846.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10856.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10877.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10882.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10883.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10887.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10889.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10904.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10908.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10942.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10947.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10948.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10950.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10955.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/sea/10967.jpg
# ...
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8774.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8794.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8818.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8842.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8844.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8848.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/886.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8864.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8866.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8871.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8876.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8880.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8885.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/889.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8907.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8919.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8925.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8928.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8931.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8947.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8949.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8958.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8970.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8974.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/898.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8981.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8995.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/8999.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9000.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9004.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9009.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9014.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9036.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9043.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9049.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9076.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/908.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9080.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9087.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9089.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9099.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/91.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9103.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9108.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9114.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9118.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9124.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9126.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9148.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9158.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9160.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9164.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9167.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9169.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9184.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9188.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9192.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9193.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9224.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9234.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9236.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9271.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9274.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9275.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9278.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9287.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9299.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/931.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9327.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9342.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9346.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9349.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9350.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9351.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9352.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9356.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9362.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/937.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9370.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9376.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9378.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/94.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9407.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9412.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9413.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9417.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9425.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9442.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9447.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9448.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/945.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/946.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9468.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9482.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9484.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9489.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9516.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9521.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9530.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9535.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9581.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9595.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9600.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9609.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9649.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9652.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9655.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9662.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9685.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9687.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9690.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9693.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/970.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9704.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9707.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/971.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9717.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9720.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9733.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9734.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/974.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9744.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9749.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9760.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9770.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9798.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9817.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9843.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9846.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9847.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9863.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9867.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9872.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9875.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9878.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9879.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9885.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9891.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9895.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9903.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9911.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/992.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9926.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9931.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9934.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/994.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9953.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9959.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9961.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9967.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9978.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/9989.jpg
#   inflating: /content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/street/999.jpg
#  extracting: /content/sprints-ai-and-ml-competition-2022-round-2/submit.csv

# %% [markdown]
# # ***Spliting Data into train and val***

# %%
# !pip install split-folders[full]
import splitfolders
# spliting Training to Train and val
split_dir = '/content/sprints-ai-and-ml-competition-2022-round-2/Scenes training set'

splitfolders.ratio(split_dir,output='output',ratio=(.85,.15))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders[full]
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from split-folders[full]) (4.64.1)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 14034 files [00:02, 6803.64 files/s]

# %% [markdown]
# # ***Data Augmentation***

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((150,150)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
    'val': transforms.Compose([
        transforms.Resize((150,150)),
        transforms.CenterCrop(150),
        transforms.ToTensor(),
        transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ]),
}


data_dir = '/content/output'

image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=14)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 14 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # ***Function to Train the Model***

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):   # we need to change number of epochs
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model
from socket import socket

# %%
# forcing using gpu
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # ***ResNet 50***

# %%
model_ft50 = models.resnet50(pretrained=True)
num_ftrs = model_ft50.fc.in_features

model_ft50.fc = nn.Linear(num_ftrs, 6)

model_ft = model_ft50.to(device)

criterion = nn.CrossEntropyLoss()


optimizer_ft = optim.SGD(model_ft50.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#model_ft50 = train_model(model_ft50, criterion, optimizer_ft, exp_lr_scheduler,
#                   num_epochs=15)

# %% [markdown]
# # ***ResNest 18***

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features

model_ft.fc = nn.Linear(num_ftrs, 6)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()


optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                   num_epochs=15)

# %% [markdown]
# # ***ConvNext_Tiny***

# %%
model_conv = torchvision.models.convnext_tiny(pretrained=True)

model_conv.classifier[2]=nn.Linear(model_conv.classifier[2].in_features, 6)


model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()


optimizer_conv = optim.SGD(model_conv.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,exp_lr_scheduler, num_epochs=17)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.6010 Acc: 0.8383
# val Loss: 0.3031 Acc: 0.9056
#
# Epoch 1/4
# ----------
# train Loss: 0.2719 Acc: 0.9101
# val Loss: 0.2385 Acc: 0.9231
#
# Epoch 2/4
# ----------
# train Loss: 0.2269 Acc: 0.9235
# val Loss: 0.2188 Acc: 0.9231
#
# Epoch 3/4
# ----------
# train Loss: 0.2035 Acc: 0.9324
# val Loss: 0.2311 Acc: 0.9194
#
# Epoch 4/4
# ----------
# train Loss: 0.1889 Acc: 0.9360
# val Loss: 0.2050 Acc: 0.9293
#
# Training complete in 8m 59s
# Best val Acc: 0.929317

# %% [markdown]
# # ***ConVNext_Small***

# %%
model_conv = torchvision.models.convnext_small(pretrained=True)

model_conv.classifier[2]=nn.Linear(model_conv.classifier[2].in_features, 6)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_conv = optim.SGD(model_conv.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ConvNeXt_Small_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/convnext_small-0c510722.pth" to /root/.cache/torch/hub/checkpoints/convnext_small-0c510722.pth
#   0%|          | 0.00/192M [00:00<?, ?B/s]

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,exp_lr_scheduler, num_epochs=17)
# Out:
# Epoch 0/16
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 14 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 0.3447 Acc: 0.8808
# val Loss: 0.2642 Acc: 0.9028
#
# Epoch 1/16
# ----------
# train Loss: 0.1993 Acc: 0.9303
# val Loss: 0.2059 Acc: 0.9307
#
# Epoch 2/16
# ----------
# train Loss: 0.1728 Acc: 0.9386
# val Loss: 0.1996 Acc: 0.9288
#
# Epoch 3/16
# ----------
# train Loss: 0.1585 Acc: 0.9424
# val Loss: 0.2025 Acc: 0.9298
#
# Epoch 4/16
# ----------
# train Loss: 0.1409 Acc: 0.9468
# val Loss: 0.1852 Acc: 0.9388
#
# Epoch 5/16
# ----------
# train Loss: 0.1325 Acc: 0.9534
# val Loss: 0.2078 Acc: 0.9312
#
# Epoch 6/16
# ----------
# train Loss: 0.1227 Acc: 0.9540
# val Loss: 0.1959 Acc: 0.9322
#
# Epoch 7/16
# ----------
# train Loss: 0.0935 Acc: 0.9689
# val Loss: 0.1814 Acc: 0.9393
#
# Epoch 8/16
# ----------
# train Loss: 0.0859 Acc: 0.9718
# val Loss: 0.1829 Acc: 0.9402
#
# Epoch 9/16
# ----------
# train Loss: 0.0805 Acc: 0.9734
# val Loss: 0.1843 Acc: 0.9412
#
# Epoch 10/16
# ----------
# train Loss: 0.0791 Acc: 0.9721
# val Loss: 0.1842 Acc: 0.9407
#
# Epoch 11/16
# ----------
# train Loss: 0.0777 Acc: 0.9735
# val Loss: 0.1877 Acc: 0.9402
#
# Epoch 12/16
# ----------
# train Loss: 0.0750 Acc: 0.9750
# val Loss: 0.1904 Acc: 0.9402
#
# Epoch 13/16
# ----------
# train Loss: 0.0730 Acc: 0.9774
# val Loss: 0.1902 Acc: 0.9374
#
# Epoch 14/16
# ----------
# train Loss: 0.0705 Acc: 0.9773
# val Loss: 0.1899 Acc: 0.9383
#
# Epoch 15/16
# ----------
# train Loss: 0.0696 Acc: 0.9773
# val Loss: 0.1898 Acc: 0.9383
#
# Epoch 16/16
# ----------
# train Loss: 0.0691 Acc: 0.9782
# val Loss: 0.1897 Acc: 0.9383
#
# Training complete in 49m 9s
# Best val Acc: 0.941176

# %% [markdown]
# # ***Saving Model***

# %%
save_dir='/content/Trained_model'
torch.save(model_conv,save_dir) #SAVES THE TRAINED MODEL

# %% [markdown]
# # ***Loading Model***

# %%
model=torch.load('/content/ConvNext Tiny')
model.eval()
# Out:
# ConvNeXt(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 96, kernel_size=(4, 4), stride=(4, 4))
#       (1): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0058823529411764705, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(96, 96, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=96)
#           (1): Permute()
#           (2): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=96, out_features=384, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=384, out_features=96, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.011764705882352941, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(96, 192, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (3): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.017647058823529415, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.023529411764705882, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(192, 192, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=192)
#           (1): Permute()
#           (2): LayerNorm((192,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=192, out_features=768, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=768, out_features=192, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.029411764705882353, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(192, 384, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (5): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.03529411764705883, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0411764705882353, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.047058823529411764, mode=row)
#       )
#       (3): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.052941176470588235, mode=row)
#       )
#       (4): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.058823529411764705, mode=row)
#       )
#       (5): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.06470588235294118, mode=row)
#       )
#       (6): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07058823529411766, mode=row)
#       )
#       (7): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.07647058823529412, mode=row)
#       )
#       (8): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(384, 384, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=384)
#           (1): Permute()
#           (2): LayerNorm((384,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=384, out_features=1536, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=1536, out_features=384, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.0823529411764706, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#       (1): Conv2d(384, 768, kernel_size=(2, 2), stride=(2, 2))
#     )
#     (7): Sequential(
#       (0): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.08823529411764706, mode=row)
#       )
#       (1): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.09411764705882353, mode=row)
#       )
#       (2): CNBlock(
#         (block): Sequential(
#           (0): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (1): Permute()
#           (2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (3): Linear(in_features=768, out_features=3072, bias=True)
#           (4): GELU(approximate=none)
#           (5): Linear(in_features=3072, out_features=768, bias=True)
#           (6): Permute()
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=768, out_features=6, bias=True)
#   )
# )

# %% [markdown]
# # ***Testing Phase***

# %%
from re import X
import PIL.Image as im
#from PIL import Image
import os
from os import listdir
from glob import glob
def predict(model,image_transforms,images_paths,classes):
    list1=[]
    list2=[]
    for i in images_paths:
     print(i)
     model=model.eval()
     image = im.open(i)
     image=image_transforms(image).to('cuda').float()
     image=image.unsqueeze(0)
     output=model(image)
     _, predicted=torch.max(output.data,1)

     print(i[-9:],predicted.item())
     list1.append(i[-9:])
     list1.append(predicted.item())
     list2.append(list1)
     list1=[]
    return list2

# %%
Test_dir='/content/sprints-ai-and-ml-competition-2022-round-2/Scenes testing test'

tranform_test = transforms.Compose([transforms.Resize((150,150)),transforms.CenterCrop(150),
        transforms.ToTensor(), transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
                 ])

# %%
x=os.listdir(Test_dir)

list_path=[]
for i in range(len(x)):
     list_path.append(Test_dir+"/"+str(x[i]))

# %%
data_frame=predict(model,tranform_test,x,class_names)

# %% [markdown]
# # ***Importing to CSV***

# %%
import pandas as pd
New_Data_Frame=pd.DataFrame(data_frame)
New_Data_Frame.to_csv('/content/sprints-ai-and-ml-competition-2022-round-2/submit.csv',index=False)
